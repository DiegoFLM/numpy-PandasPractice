# %%
import pandas as pd

# %%
df_bestSellers = pd.read_csv('files/bestsellers-with-categories.csv', sep = ',', header = 0, 
    names = ['Book', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre']
    )
df_bestSellers
# Out:
#                                                   Book  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_bestSellers.columns
# Out:
# Index(['Book', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %% [markdown]
# # .json

# %%
HPchars = pd.read_json('files/hpcharactersdataraw.json') #, typ = 'Series')
HPchars
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %%
HPchars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1940 entries, 0 to 1939
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1940 non-null   object
#  1   Link          1940 non-null   object
#  2   Descr         1940 non-null   object
#  3   Gender        1940 non-null   object
#  4   Species/Race  1940 non-null   object
#  5   Blood         1940 non-null   object
#  6   School        1940 non-null   object
#  7   Profession    1940 non-null   object
# dtypes: object(8)
# memory usage: 121.4+ KB

# %% [markdown]
# # CO2 Emissions in metric tons per capita

# %%
ghg = pd.read_csv('files/ghg-emissions.csv', nrows = 193)  #, skiprows=2)
ghg
# Out:
#     Country/Region    unit     1990     1991     1992     1993     1994  \
# 0            China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1    United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2            India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
# 3        Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 4           Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
# ..             ...     ...      ...      ...      ...      ...      ...
# 188   Cook Islands  MtCO2e     0.03     0.03     0.03     0.04     0.04
# 189          Nauru  MtCO2e     0.13     0.13     0.12     0.12     0.12
# 190         Tuvalu  MtCO2e     0.02     0.02     0.02     0.02     0.02
# 191           Niue  MtCO2e     0.01     0.01     0.01     0.01     0.01
# 192           Fiji  MtCO2e    -0.82    -0.81    -0.77    -0.71    -0.66
#
#         1995     1996     1997  ...     2010      2011      2012      2013  \
# ...

# %%
ghg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  193 non-null    object
#  1   unit            193 non-null    object
#  2   1990            193 non-null    object
#  3   1991            193 non-null    float64
#  4   1992            193 non-null    float64
#  5   1993            193 non-null    float64
#  6   1994            193 non-null    float64
#  7   1995            193 non-null    float64
#  8   1996            193 non-null    float64
#  9   1997            193 non-null    float64
#  10  1998            193 non-null    float64
#  11  1999            193 non-null    float64
#  12  2000            193 non-null    float64
#  13  2001            193 non-null    float64
#  14  2002            193 non-null    float64
#  15  2003            193 non-null    float64
#  16  2004            193 non-null    float64
# ...

# %%
#ghg[:4]
#ghg['1990']
ghg[['Country/Region', '1990', '2019']] 
#ghg['Country/Region'] == 'China'
china = ghg[ghg['Country/Region'] == 'China']
china
# Out:
#   Country/Region    unit     1990     1991     1992    1993     1994    1995  \
# 0          China  MtCO2e  2891.73  3039.14  3168.05  3397.8  3557.37  3960.7
#
#       1996     1997  ...     2010      2011      2012      2013      2014  \
# 0  3982.11  3977.65  ...  9887.06  10388.48  10675.66  11168.26  11228.48
#
#        2015      2016      2017      2018      2019
# 0  11108.86  11151.31  11385.48  11821.66  12055.41
#
# [1 rows x 32 columns]

# %% [markdown]
# # np.loc & np.iloc

# %%
ghg.loc[0:4 ,['Country/Region', '2019']]
# Out:
#   Country/Region      2019
# 0          China  12055.41
# 1  United States   5771.00
# 2          India   3363.59
# 3      Indonesia   1959.71
# 4         Russia   1924.82

# %%
ghg.iloc[:, 0:5]
# Out:
#     Country/Region    unit     1990     1991     1992
# 0            China  MtCO2e  2891.73  3039.14  3168.05
# 1    United States  MtCO2e  5417.32  5372.07  5456.12
# 2            India  MtCO2e  1002.56  1056.25  1081.28
# 3        Indonesia  MtCO2e  1226.82  1246.27  1266.98
# 4           Russia  MtCO2e  2648.36  2585.28  2428.18
# ..             ...     ...      ...      ...      ...
# 188   Cook Islands  MtCO2e     0.03     0.03     0.03
# 189          Nauru  MtCO2e     0.13     0.13     0.12
# 190         Tuvalu  MtCO2e     0.02     0.02     0.02
# 191           Niue  MtCO2e     0.01     0.01     0.01
# 192           Fiji  MtCO2e    -0.82    -0.81    -0.77
#
# [193 rows x 5 columns]

# %%
ghg.iloc[:3, 2:]
# Out:
#       1990     1991     1992     1993     1994     1995     1996     1997  \
# 0  2891.73  3039.14  3168.05  3397.80  3557.37  3960.70  3982.11  3977.65
# 1  5417.32  5372.07  5456.12  5567.55  5661.57  5729.69  5901.00  6160.86
# 2  1002.56  1056.25  1081.28  1114.22  1158.48  1223.65  1272.74  1331.88
#
#       1998     1999  ...     2010      2011      2012      2013      2014  \
# 0  4095.97  4028.58  ...  9887.06  10388.48  10675.66  11168.26  11228.48
# 1  6208.83  6210.12  ...  6026.14   5811.96   5593.24   5734.28   5779.53
# 2  1362.33  1440.38  ...  2546.79   2584.75   2740.40   2804.34   2984.52
#
#        2015      2016      2017      2018      2019
# 0  11108.86  11151.31  11385.48  11821.66  12055.41
# 1   5665.20   5743.85   5689.61   5892.37   5771.00
# 2   3003.07   3076.48   3215.07   3360.56   3363.59
#
# [3 rows x 30 columns]

# %%
arr1 = np.array(ghg['1990'])
df = pd.DataFrame(arr1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       193 non-null    object
# dtypes: object(1)
# memory usage: 1.6+ KB

# %%
import numpy as np

# %%
arr1 = np.array(ghg['1990'])
#print(arr1)
print(arr1[arr1 == 'false'])
arr1[arr1 == 'false'] = -100000000000000
#print(arr1)
floatArr = np.array(arr1, dtype='float64')
    #ow: #floatArr = arr1.astype('float64')
print(floatArr)
# Out:
# ['false']
# [ 2.89173e+03  5.41732e+03  1.00256e+03  1.22682e+03  2.64836e+03
#   1.63868e+03  1.10626e+03  3.04220e+02  6.06910e+02  2.41010e+02
#   1.07716e+03  4.30770e+02  4.26290e+02  2.38320e+02  5.41390e+02
#   3.38430e+02  1.88500e+02  1.67900e+02  2.12000e+00  1.73050e+02
#   7.33870e+02  2.92650e+02  1.97120e+02  4.48750e+02  2.67920e+02
#   4.71020e+02  1.33650e+02  1.20150e+02  4.07180e+02  3.96960e+02
#   2.32970e+02  1.21400e+02  2.95960e+02  2.16210e+02  7.32500e+01
#   2.08110e+02  1.16940e+02  9.79800e+01  7.76110e+02  1.04150e+02
#   1.64440e+02  9.51400e+01  2.03820e+02  1.11390e+02  9.82000e+01
#   1.12970e+02  3.90400e+01  6.61600e+01  7.06600e+01  8.74300e+01
#   7.36100e+01  4.26900e+01  1.53800e+01  1.72530e+02  1.26860e+02
#   8.34200e+01  2.49200e+01  1.94400e+01  7.35200e+01  7.51800e+01
#   5.95400e+01  3.19100e+01  4.40800e+01  1.61170e+02  9.43100e+01
#   2.24740e+02  3.06500e+01  4.52400e+01  2.48300e+01  6.31400e+01
# ...

# %% [markdown]
# # Data Manipulation

# %%
import pandas as pd

# %%
ghg = pd.read_csv('files/ghg-emissions.csv', nrows = 193)  #, skiprows=2)
ghg.head(3)
# Out:
#   Country/Region    unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1  United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2          India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
#
#       1995     1996     1997  ...     2010      2011      2012      2013  \
# 0  3960.70  3982.11  3977.65  ...  9887.06  10388.48  10675.66  11168.26
# 1  5729.69  5901.00  6160.86  ...  6026.14   5811.96   5593.24   5734.28
# 2  1223.65  1272.74  1331.88  ...  2546.79   2584.75   2740.40   2804.34
#
#        2014      2015      2016      2017      2018      2019
# 0  11228.48  11108.86  11151.31  11385.48  11821.66  12055.41
# 1   5779.53   5665.20   5743.85   5689.61   5892.37   5771.00
# 2   2984.52   3003.07   3076.48   3215.07   3360.56   3363.59
#
# [3 rows x 32 columns]

# %% [markdown]
# ### Drop columns:

# %%
ghgDrop = ghg.drop('1991', axis = 1)
ghg.head()
# Out:
#   Country/Region    unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1  United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2          India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
# 3      Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 4         Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
#
#       1995     1996     1997  ...     2010      2011      2012      2013  \
# 0  3960.70  3982.11  3977.65  ...  9887.06  10388.48  10675.66  11168.26
# 1  5729.69  5901.00  6160.86  ...  6026.14   5811.96   5593.24   5734.28
# 2  1223.65  1272.74  1331.88  ...  2546.79   2584.75   2740.40   2804.34
# 3  1339.10  1164.23  2134.80  ...  1131.73   1683.13   1702.30   1638.39
# 4  1918.33  1874.95  1723.24  ...  1521.96   1693.95   1674.58   1633.10
#
#        2014      2015      2016      2017      2018      2019
# ...

# %%
ghgDrop.head()
# Out:
#   Country/Region    unit     1990     1992     1993     1994     1995  \
# 0          China  MtCO2e  2891.73  3168.05  3397.80  3557.37  3960.70
# 1  United States  MtCO2e  5417.32  5456.12  5567.55  5661.57  5729.69
# 2          India  MtCO2e  1002.56  1081.28  1114.22  1158.48  1223.65
# 3      Indonesia  MtCO2e  1226.82  1266.98  1282.35  1302.70  1339.10
# 4         Russia  MtCO2e  2648.36  2428.18  2233.86  1995.87  1918.33
#
#       1996     1997     1998  ...     2010      2011      2012      2013  \
# 0  3982.11  3977.65  4095.97  ...  9887.06  10388.48  10675.66  11168.26
# 1  5901.00  6160.86  6208.83  ...  6026.14   5811.96   5593.24   5734.28
# 2  1272.74  1331.88  1362.33  ...  2546.79   2584.75   2740.40   2804.34
# 3  1164.23  2134.80  1366.90  ...  1131.73   1683.13   1702.30   1638.39
# 4  1874.95  1723.24  1725.07  ...  1521.96   1693.95   1674.58   1633.10
#
#        2014      2015      2016      2017      2018      2019
# ...

# %%
ghg.drop('1991', axis = 1, inplace = True)
ghg.head()
# Out:
#   Country/Region    unit     1990     1992     1993     1994     1995  \
# 0          China  MtCO2e  2891.73  3168.05  3397.80  3557.37  3960.70
# 1  United States  MtCO2e  5417.32  5456.12  5567.55  5661.57  5729.69
# 2          India  MtCO2e  1002.56  1081.28  1114.22  1158.48  1223.65
# 3      Indonesia  MtCO2e  1226.82  1266.98  1282.35  1302.70  1339.10
# 4         Russia  MtCO2e  2648.36  2428.18  2233.86  1995.87  1918.33
#
#       1996     1997     1998  ...     2010      2011      2012      2013  \
# 0  3982.11  3977.65  4095.97  ...  9887.06  10388.48  10675.66  11168.26
# 1  5901.00  6160.86  6208.83  ...  6026.14   5811.96   5593.24   5734.28
# 2  1272.74  1331.88  1362.33  ...  2546.79   2584.75   2740.40   2804.34
# 3  1164.23  2134.80  1366.90  ...  1131.73   1683.13   1702.30   1638.39
# 4  1874.95  1723.24  1725.07  ...  1521.96   1693.95   1674.58   1633.10
#
#        2014      2015      2016      2017      2018      2019
# ...

# %% [markdown]
# ### Drop rows:

# %%
ghg = pd.read_csv('files/ghg-emissions.csv', nrows = 193)  #, skiprows=2)
ghg.head()
# Out:
#   Country/Region    unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1  United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2          India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
# 3      Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 4         Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
#
#       1995     1996     1997  ...     2010      2011      2012      2013  \
# 0  3960.70  3982.11  3977.65  ...  9887.06  10388.48  10675.66  11168.26
# 1  5729.69  5901.00  6160.86  ...  6026.14   5811.96   5593.24   5734.28
# 2  1223.65  1272.74  1331.88  ...  2546.79   2584.75   2740.40   2804.34
# 3  1339.10  1164.23  2134.80  ...  1131.73   1683.13   1702.30   1638.39
# 4  1918.33  1874.95  1723.24  ...  1521.96   1693.95   1674.58   1633.10
#
#        2014      2015      2016      2017      2018      2019
# ...

# %%
#ghg.drop(1, axis = 0, inplace = True)
#ghg.drop([1, 2, 3], axis = 0, inplace = True)
ghg.drop(range(2, 7), axis = 0, inplace = True)
ghg.head()
# Out:
#   Country/Region    unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1  United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 7           Iran  MtCO2e   304.22   332.58   354.38   362.41   394.82
# 8         Canada  MtCO2e   606.91   602.81   617.15   613.16   631.24
# 9   Saudi Arabia  MtCO2e   241.01   274.22   291.77   289.62   289.30
#
#       1995     1996     1997  ...     2010      2011      2012      2013  \
# 0  3960.70  3982.11  3977.65  ...  9887.06  10388.48  10675.66  11168.26
# 1  5729.69  5901.00  6160.86  ...  6026.14   5811.96   5593.24   5734.28
# 7   405.33   420.32   439.31  ...   737.61    793.62    793.95    815.31
# 8   646.48   668.42   679.96  ...   971.61    821.99    822.51    834.47
# 9   288.63   304.34   310.73  ...   569.68    601.75    638.88    654.85
#
#        2014      2015      2016      2017      2018      2019
# ...

# %%
print(ghg['2019'].max())
ghg[ghg['2019'] == 12055.41]
# Out:
# 12055.41
#   Country/Region    unit     1990     1991     1992    1993     1994    1995  \
# 0          China  MtCO2e  2891.73  3039.14  3168.05  3397.8  3557.37  3960.7
#
#       1996     1997  ...     2010      2011      2012      2013      2014  \
# 0  3982.11  3977.65  ...  9887.06  10388.48  10675.66  11168.26  11228.48
#
#        2015      2016      2017      2018      2019
# 0  11108.86  11151.31  11385.48  11821.66  12055.41
#
# [1 rows x 32 columns]

# %% [markdown]
# ### Adding columns:

# %%
import numpy as np
import pandas as pd

# %%
ghg = pd.read_csv('files/ghg-emissions.csv', nrows = 193)  #, skiprows=2)
ghg.head()
# Out:
#   Country/Region    unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1  United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2          India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
# 3      Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 4         Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
#
#       1995     1996     1997  ...     2010      2011      2012      2013  \
# 0  3960.70  3982.11  3977.65  ...  9887.06  10388.48  10675.66  11168.26
# 1  5729.69  5901.00  6160.86  ...  6026.14   5811.96   5593.24   5734.28
# 2  1223.65  1272.74  1331.88  ...  2546.79   2584.75   2740.40   2804.34
# 3  1339.10  1164.23  2134.80  ...  1131.73   1683.13   1702.30   1638.39
# 4  1918.33  1874.95  1723.24  ...  1521.96   1693.95   1674.58   1633.10
#
#        2014      2015      2016      2017      2018      2019
# ...

# %%
ghg['newCol'] = ghg['1991'] + ghg['1992']
ghg.head()
# Out:
#   Country/Region    unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1  United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2          India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
# 3      Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 4         Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
#
#       1995     1996     1997  ...      2011      2012      2013      2014  \
# 0  3960.70  3982.11  3977.65  ...  10388.48  10675.66  11168.26  11228.48
# 1  5729.69  5901.00  6160.86  ...   5811.96   5593.24   5734.28   5779.53
# 2  1223.65  1272.74  1331.88  ...   2584.75   2740.40   2804.34   2984.52
# 3  1339.10  1164.23  2134.80  ...   1683.13   1702.30   1638.39   2015.50
# 4  1918.33  1874.95  1723.24  ...   1693.95   1674.58   1633.10   1621.85
#
#        2015      2016      2017      2018      2019    newCol
# ...

# %% [markdown]
# ### Adding rows

# %%
ghg
# Out:
#     Country/Region    unit     1990     1991     1992     1993     1994  \
# 0            China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1    United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2            India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
# 3        Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 4           Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
# ..             ...     ...      ...      ...      ...      ...      ...
# 188   Cook Islands  MtCO2e     0.03     0.03     0.03     0.04     0.04
# 189          Nauru  MtCO2e     0.13     0.13     0.12     0.12     0.12
# 190         Tuvalu  MtCO2e     0.02     0.02     0.02     0.02     0.02
# 191           Niue  MtCO2e     0.01     0.01     0.01     0.01     0.01
# 192           Fiji  MtCO2e    -0.82    -0.81    -0.77    -0.71    -0.66
#
#         1995     1996     1997  ...      2011      2012      2013      2014  \
# ...

# %%
ghg.append(ghg)
# Out:
# /tmp/ipykernel_19073/224805153.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ghg.append(ghg)
#     Country/Region    unit     1990     1991     1992     1993     1994  \
# 0            China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1    United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2            India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
# 3        Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 4           Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
# ..             ...     ...      ...      ...      ...      ...      ...
# 188   Cook Islands  MtCO2e     0.03     0.03     0.03     0.04     0.04
# 189          Nauru  MtCO2e     0.13     0.13     0.12     0.12     0.12
# 190         Tuvalu  MtCO2e     0.02     0.02     0.02     0.02     0.02
# ...
