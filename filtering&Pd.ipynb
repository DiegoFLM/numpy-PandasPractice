# %%
import numpy as np
import pandas as pd

# %%
ghg = pd.read_csv('files/ghg-emissions.csv', nrows = 193) 
ghg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  193 non-null    object
#  1   unit            193 non-null    object
#  2   1990            193 non-null    object
#  3   1991            193 non-null    float64
#  4   1992            193 non-null    float64
#  5   1993            193 non-null    float64
#  6   1994            193 non-null    float64
#  7   1995            193 non-null    float64
#  8   1996            193 non-null    float64
#  9   1997            193 non-null    float64
#  10  1998            193 non-null    float64
#  11  1999            193 non-null    float64
#  12  2000            193 non-null    float64
#  13  2001            193 non-null    float64
#  14  2002            193 non-null    float64
#  15  2003            193 non-null    float64
#  16  2004            193 non-null    float64
# ...

# %%
ghg.head()
# Out:
#   Country/Region    unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1  United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2          India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
# 3      Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 4         Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
#
#       1995     1996     1997  ...     2010      2011      2012      2013  \
# 0  3960.70  3982.11  3977.65  ...  9887.06  10388.48  10675.66  11168.26
# 1  5729.69  5901.00  6160.86  ...  6026.14   5811.96   5593.24   5734.28
# 2  1223.65  1272.74  1331.88  ...  2546.79   2584.75   2740.40   2804.34
# 3  1339.10  1164.23  2134.80  ...  1131.73   1683.13   1702.30   1638.39
# 4  1918.33  1874.95  1723.24  ...  1521.96   1693.95   1674.58   1633.10
#
#        2014      2015      2016      2017      2018      2019
# ...

# %%
cond = ghg['2019'] > ghg['2019'].mean()
ghg[cond]
# Out:
#                       Country/Region    unit     1990     1991     1992  \
# 0                              China  MtCO2e  2891.73  3039.14  3168.05
# 1                      United States  MtCO2e  5417.32  5372.07  5456.12
# 2                              India  MtCO2e  1002.56  1056.25  1081.28
# 3                          Indonesia  MtCO2e  1226.82  1246.27  1266.98
# 4                             Russia  MtCO2e  2648.36  2585.28  2428.18
# 5                             Brazil  MtCO2e  1638.68  1659.83  1669.79
# 6                              Japan  MtCO2e  1106.26  1121.71  1134.81
# 7                               Iran  MtCO2e   304.22   332.58   354.38
# 8                             Canada  MtCO2e   606.91   602.81   617.15
# 9                       Saudi Arabia  MtCO2e   241.01   274.22   291.77
# 10                           Germany  MtCO2e  1077.16  1049.84  1004.45
# 11  Democratic Republic of the Congo  MtCO2e   430.77   429.39   429.54
# ...

# %% [markdown]
# # Denied condition

# %%
deniedCond = ghg['2019'] > ghg['2019'].mean()
ghg[~deniedCond]
# Out:
#            Country/Region    unit    1990    1991    1992    1993    1994  \
# 34   United Arab Emirates  MtCO2e   73.25   81.07   79.19   83.62   92.20
# 35                Myanmar  MtCO2e  208.11  207.52  210.26  212.93  215.57
# 36             Bangladesh  MtCO2e  116.94  117.15  119.30  120.75  123.37
# 37            Philippines  MtCO2e   97.98   97.84   99.86  105.28  112.50
# 38                Ukraine  MtCO2e  776.11  733.77  644.43  560.95  471.12
# ..                    ...     ...     ...     ...     ...     ...     ...
# 188          Cook Islands  MtCO2e    0.03    0.03    0.03    0.04    0.04
# 189                 Nauru  MtCO2e    0.13    0.13    0.12    0.12    0.12
# 190                Tuvalu  MtCO2e    0.02    0.02    0.02    0.02    0.02
# 191                  Niue  MtCO2e    0.01    0.01    0.01    0.01    0.01
# 192                  Fiji  MtCO2e   -0.82   -0.81   -0.77   -0.71   -0.66
#
#        1995    1996    1997  ...    2010    2011    2012    2013    2014  \
# ...

# %% [markdown]
# # Pandas Basics

# %%
import numpy as np
import pandas as pd

# %%
ghg = pd.read_csv('files/ghg-emissions.csv', nrows = 193) 
ghg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  193 non-null    object
#  1   unit            193 non-null    object
#  2   1990            193 non-null    object
#  3   1991            193 non-null    float64
#  4   1992            193 non-null    float64
#  5   1993            193 non-null    float64
#  6   1994            193 non-null    float64
#  7   1995            193 non-null    float64
#  8   1996            193 non-null    float64
#  9   1997            193 non-null    float64
#  10  1998            193 non-null    float64
#  11  1999            193 non-null    float64
#  12  2000            193 non-null    float64
#  13  2001            193 non-null    float64
#  14  2002            193 non-null    float64
#  15  2003            193 non-null    float64
#  16  2004            193 non-null    float64
# ...

# %% [markdown]
# # Fixing the 'false' value in the column '1990' and the dtype of that column

# %%
ghg[ghg['Country/Region'] == 'Namibia']#['1990']
# Out:
#     Country/Region    unit   1990   1991   1992   1993   1994   1995   1996  \
# 120        Namibia  MtCO2e  false  19.82  19.77  19.74  19.94  20.05  19.92
#
#       1997  ...   2010   2011   2012   2013   2014   2015   2016   2017  \
# 120  19.76  ...  23.23  28.21  29.75  22.93  22.18  22.29  22.86  23.04
#
#       2018   2019
# 120  22.17  21.22
#
# [1 rows x 32 columns]

# %%
mean1990 = ghg[ghg['1990'] != 'false']['1990'].astype('float64').mean()
print(mean1990)
#ghg[ghg['1990'] == 'false']
ghg[ghg['1990'] == 'false']['1990'] = mean1990
ghg.loc[ghg['1990'] == 'false', '1990'] = mean1990
#print(ghg[ghg['1990'] == mean1990])
ghg['1990'] = ghg['1990'].astype('float64')
ghg[ghg['Country/Region'] == "Namibia"]
ghg[ghg['Country/Region'] == "Namibia"]['1990']
#ghg.info()
#ghg.head()
# Out:
# 163.18562500000004
# /tmp/ipykernel_27328/3626341632.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ghg[ghg['1990'] == 'false']['1990'] = mean1990
# 120    163.185625
# Name: 1990, dtype: float64

# %%
ghg.describe()
# Out:
#               1990         1991         1992         1993         1994  \
# count   193.000000   193.000000   193.000000   193.000000   193.000000
# mean    163.185625   163.167358   163.167047   163.944249   165.309430
# std     517.653552   519.008153   523.465071   532.331107   539.227531
# min      -5.820000    -5.780000    -5.820000    -5.810000    -5.800000
# 25%       7.010000     6.890000     6.950000     7.090000     6.850000
# 50%      30.340000    28.240000    26.800000    25.870000    26.600000
# 75%      97.980000    94.380000    86.090000    90.480000    99.440000
# max    5417.320000  5372.070000  5456.120000  5567.550000  5661.570000
#
#              1995         1996         1997         1998         1999  ...  \
# count   193.00000   193.000000   193.000000   193.000000   193.000000  ...
# mean    169.25886   171.081451   177.910725   175.451347   175.216528  ...
# std     556.93240   565.530125   590.544976   586.794656   584.927745  ...
# ...

# %%
ghg.tail()
# Out:
#     Country/Region    unit  1990  1991  1992  1993  1994  1995  1996  1997  \
# 188   Cook Islands  MtCO2e  0.03  0.03  0.03  0.04  0.04  0.04  0.05  0.05
# 189          Nauru  MtCO2e  0.13  0.13  0.12  0.12  0.12  0.11  0.11  0.11
# 190         Tuvalu  MtCO2e  0.02  0.02  0.02  0.02  0.02  0.02  0.02  0.02
# 191           Niue  MtCO2e  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01
# 192           Fiji  MtCO2e -0.82 -0.81 -0.77 -0.71 -0.66 -0.60 -0.56 -0.56
#
#      ...  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 188  ...  0.08  0.09  0.09  0.09  0.09  0.08  0.09  0.10  0.10  0.10
# 189  ...  0.05  0.04  0.05  0.05  0.06  0.06  0.07  0.07  0.07  0.07
# 190  ...  0.02  0.02  0.02  0.02  0.02  0.02  0.02  0.02  0.03  0.03
# 191  ...  0.01  0.00  0.00  0.00  0.00  0.01  0.01  0.01  0.01  0.01
# 192  ... -0.24 -0.29 -0.37 -0.25 -0.66 -0.54 -0.41 -0.22 -0.24 -0.16
#
# [5 rows x 32 columns]

# %%
ghg.memory_usage(deep = True)
# Out:
# Index               128
# Country/Region    12673
# unit              12159
# 1990               1544
# 1991               1544
# 1992               1544
# 1993               1544
# 1994               1544
# 1995               1544
# 1996               1544
# 1997               1544
# 1998               1544
# 1999               1544
# 2000               1544
# 2001               1544
# 2002               1544
# 2003               1544
# 2004               1544
# 2005               1544
# 2006               1544
# 2007               1544
# 2008               1544
# 2009               1544
# 2010               1544
# 2011               1544
# 2012               1544
# 2013               1544
# 2014               1544
# 2015               1544
# 2016               1544
# 2017               1544
# 2018               1544
# 2019               1544
# dtype: int64

# %%
#ghg['Country/Region'].value_counts()
ghg['unit'].value_counts()
# Out:
# MtCO2e    193
# Name: unit, dtype: int64

# %%
ghg.iloc[0] #first row
ghg = ghg.append( ghg.iloc[0] )
ghg
ghg.drop_duplicates(keep = 'first', inplace = True)
ghg
# Out:
# /tmp/ipykernel_27328/4175563500.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ghg = ghg.append( ghg.iloc[0] )
#     Country/Region    unit     1990     1991     1992     1993     1994  \
# 0            China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 1    United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 2            India  MtCO2e  1002.56  1056.25  1081.28  1114.22  1158.48
# 3        Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 4           Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
# ..             ...     ...      ...      ...      ...      ...      ...
# 188   Cook Islands  MtCO2e     0.03     0.03     0.03     0.04     0.04
# 189          Nauru  MtCO2e     0.13     0.13     0.12     0.12     0.12
# 190         Tuvalu  MtCO2e     0.02     0.02     0.02     0.02     0.02
# ...

# %%
ghg.sort_values('1997', ascending = False)
# Out:
#     Country/Region    unit     1990     1991     1992     1993     1994  \
# 1    United States  MtCO2e  5417.32  5372.07  5456.12  5567.55  5661.57
# 0            China  MtCO2e  2891.73  3039.14  3168.05  3397.80  3557.37
# 3        Indonesia  MtCO2e  1226.82  1246.27  1266.98  1282.35  1302.70
# 5           Brazil  MtCO2e  1638.68  1659.83  1669.79  1681.12  1697.94
# 4           Russia  MtCO2e  2648.36  2585.28  2428.18  2233.86  1995.87
# ..             ...     ...      ...      ...      ...      ...      ...
# 173     Cape Verde  MtCO2e    -0.29    -0.27    -0.24    -0.23    -0.25
# 146         Latvia  MtCO2e    12.42    10.70     8.03     4.85     1.88
# 192           Fiji  MtCO2e    -0.82    -0.81    -0.77    -0.71    -0.66
# 126        Georgia  MtCO2e    31.40    21.95    14.39     8.86     1.70
# 178         Bhutan  MtCO2e    -5.82    -5.78    -5.82    -5.81    -5.80
#
#         1995     1996     1997  ...     2010      2011      2012      2013  \
# ...
